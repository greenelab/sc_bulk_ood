# %% [markdown]
# # Intro
#
# Here we use ALL perturbed cell-types.
# This is done when we generate the pseudobulks by sampling from both perturbed or non-perturbed cells within each sample.
#
# This data QCs the Kang et.al. data to make sure everything looks good.
# The data was retreived using  the SeuratData package in R and then translated into an AnnData object to be read into python,
# Notebook for SeuratData analysis of Kang data (names ifnb in SeuratData): https://satijalab.org/seurat/articles/integration_introduction.html
# Seurat Disk was used for conversion between h5Seurat and AnnData: https://mojaveazure.github.io/seurat-disk/articles/convert-anndata.html
#
# Kang data is originally from here:
# Kang, Hyun Min, et al. "Multiplexed droplet single-cell RNA-sequencing using natural genetic variation." Nature biotechnology 36.1 (2018): 89-94.
#
# This based off of the tutorial from scanpy using pbmc 3K.
# https://scanpy-tutorials.readthedocs.io/en/latest/pbmc3k.html
#
# And heavily influenced by https://github.com/theislab/scanpy_usage/blob/master/170503_zheng17/zheng17.ipynb

# %% [markdown]
# # Imports

# %%
import sys
sys.path.insert(1, '../../')
sys.path.insert(1, '../')
from sc_preprocessing import sc_preprocess


# general imports
import warnings
import numpy as np
import os
import pandas as pd
import scipy as sp
from scipy.sparse import coo_matrix
import collections
import scanpy as sc


# Images, plots, display, and visualization
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
from sklearn.manifold import TSNE
import sklearn as sk

# matplotlib settings for Jupyter notebooks only
# %matplotlib inline

import pickle
import gzip
from pathlib import Path

# %%
from importlib import reload  # Python 3.4+
reload(sc_preprocess)
# Out:
# <module 'sc_preprocessing.sc_preprocess' from '/beevol/home/davidson/checkouts/sc_bulk_ood/sc_preprocessing/2_make_pseudobulks/../../sc_preprocessing/sc_preprocess.py'>

# %% [markdown]
# # Parameters

# %%
# parameters

aug_data_path = f"{os.getcwd()}/../../data/single_cell_data/augmented_liver_data/"
cibersort_path = f"{os.getcwd()}/../../data/single_cell_data/cibersort_liver/"
data_path = f"{os.getcwd()}/../../data/single_cell_data/liver_sex/"



#####################
### set the study ###
#####################

res_name = "all-liver"
in_name = "liver_droplet_processed"
processed_sc_file = f"{data_path}/{in_name}.h5ad"

# %% [markdown]
# # Load and Process data

# %% [markdown]
# ### Read in data and metadata

# %%
# read in the data

adata = sc.read_h5ad(processed_sc_file)

adata.var_names_make_unique()  # this is unnecessary if using `var_names='gene_ids'` in `sc.read_10x_mtx`

# %%
# format metadata


def get_stim_id(in_str):
    out_str = "STIM"
    if in_str == "male":
        out_str = "CTRL"
           
    return(out_str)


adata.obs['CellType'] = adata.obs['names_merged'].tolist()
adata.obs['scpred_CellType'] = adata.obs['names_merged'].tolist()
adata.obs['sample_id'] = adata.obs['mouse.id'].tolist()
adata.obs['stim'] = [get_stim_id(str(x)) for x in adata.obs['sex'].tolist()]

adata.var['gene_ids'] = adata.var.index.tolist()

# %%
np.where(adata.var['gene_ids'] == "Cd74")
# Out:
# (array([6468]),)

# %%
# we are going to combine a few cell types
tab = adata.obs.groupby(['sample_id', 'stim']).size()

tab.unstack()
# Out:
# stim         CTRL   STIM
# sample_id
# 1-M-63     1933.0    NaN
# AAAGTAGAGGCCCTTG-1-9-0-0   Hepatocyte (Pericentral, Midlobular, Periportal)
# AACCGCGAGAAACCGC-1-9-0-0   Hepatocyte (Pericentral, Midlobular, Periportal)
# AACTCCCAGTTGTCGT-1-9-0-0   Hepatocyte (Pericentral, Midlobular, Periportal)
# AACTCCCGTAACGTTC-1-9-0-0   Hepatocyte (Pericentral, Midlobular, Periportal)
# ...                                                                     ...
# TTTGCGCTCGTTTATC-1-50-1-0                                      Kupffer cell
# TTTGGTTAGAACTGTA-1-50-1-0                          Hepatocyte (Pericentral)
# TTTGGTTAGGAGTACC-1-50-1-0                                      Kupffer cell
# TTTGGTTGTAGCGCAA-1-50-1-0                                      Kupffer cell
# TTTGTCACAAATCCGT-1-50-1-0                                              NK/T
#
#                             method mouse.id  n_genes     sex  ...  \
# index                                                         ...
# AAAGCAATCGGAAATA-1-9-0-0   droplet  18-F-51     1976  female  ...
# AAAGTAGAGGCCCTTG-1-9-0-0   droplet  18-F-51     1897  female  ...
# AACCGCGAGAAACCGC-1-9-0-0   droplet  18-F-51     1501  female  ...
# AACTCCCAGTTGTCGT-1-9-0-0   droplet  18-F-51     1710  female  ...
# AACTCCCGTAACGTTC-1-9-0-0   droplet  18-F-51     1432  female  ...
# ...                            ...      ...      ...     ...  ...
# TTTGCGCTCGTTTATC-1-50-1-0  droplet   1-M-63     1856    male  ...
# TTTGGTTAGAACTGTA-1-50-1-0  droplet   1-M-63     1404    male  ...
# TTTGGTTAGGAGTACC-1-50-1-0  droplet   1-M-63     2694    male  ...
# TTTGGTTGTAGCGCAA-1-50-1-0  droplet   1-M-63     2359    male  ...
# TTTGTCACAAATCCGT-1-50-1-0  droplet   1-M-63     1483    male  ...
#
#                           names_merged keep n_genes_by_counts  total_counts  \
# index
# AAAGCAATCGGAAATA-1-9-0-0    hepatocyte  yes              1976   7407.838867
# AAAGTAGAGGCCCTTG-1-9-0-0    hepatocyte  yes              1897   7719.286621
# AACCGCGAGAAACCGC-1-9-0-0    hepatocyte  yes              1501   6661.215332
# AACTCCCAGTTGTCGT-1-9-0-0    hepatocyte  yes              1710   6938.270020
# AACTCCCGTAACGTTC-1-9-0-0    hepatocyte  yes              1432   6389.012695
# ...                                ...  ...               ...           ...
# TTTGCGCTCGTTTATC-1-50-1-0      kupffer  yes              1856   5283.314453
# TTTGGTTAGAACTGTA-1-50-1-0   hepatocyte  yes              1403   4763.772461
# TTTGGTTAGGAGTACC-1-50-1-0      kupffer  yes              2694   6832.473633
# TTTGGTTGTAGCGCAA-1-50-1-0      kupffer  yes              2359   6148.290039
# TTTGTCACAAATCCGT-1-50-1-0           NK  yes              1483   4487.968262
#
#                           total_counts_mt pct_counts_mt    CellType  \
# index
# AAAGCAATCGGAAATA-1-9-0-0              0.0           0.0  hepatocyte
# AAAGTAGAGGCCCTTG-1-9-0-0              0.0           0.0  hepatocyte
# AACCGCGAGAAACCGC-1-9-0-0              0.0           0.0  hepatocyte
# AACTCCCAGTTGTCGT-1-9-0-0              0.0           0.0  hepatocyte
# AACTCCCGTAACGTTC-1-9-0-0              0.0           0.0  hepatocyte
# ...                                   ...           ...         ...
# TTTGCGCTCGTTTATC-1-50-1-0             0.0           0.0     kupffer
# TTTGGTTAGAACTGTA-1-50-1-0             0.0           0.0  hepatocyte
# TTTGGTTAGGAGTACC-1-50-1-0             0.0           0.0     kupffer
# TTTGGTTGTAGCGCAA-1-50-1-0             0.0           0.0     kupffer
# TTTGTCACAAATCCGT-1-50-1-0             0.0           0.0          NK
#
#                           scpred_CellType  sample_id  stim
# index
# AAAGCAATCGGAAATA-1-9-0-0       hepatocyte    18-F-51  STIM
# AAAGTAGAGGCCCTTG-1-9-0-0       hepatocyte    18-F-51  STIM
# AACCGCGAGAAACCGC-1-9-0-0       hepatocyte    18-F-51  STIM
# AACTCCCAGTTGTCGT-1-9-0-0       hepatocyte    18-F-51  STIM
# AACTCCCGTAACGTTC-1-9-0-0       hepatocyte    18-F-51  STIM
# ...                                   ...        ...   ...
# TTTGCGCTCGTTTATC-1-50-1-0         kupffer     1-M-63  CTRL
# TTTGGTTAGAACTGTA-1-50-1-0      hepatocyte     1-M-63  CTRL
# TTTGGTTAGGAGTACC-1-50-1-0         kupffer     1-M-63  CTRL
# TTTGGTTGTAGCGCAA-1-50-1-0         kupffer     1-M-63  CTRL
# TTTGTCACAAATCCGT-1-50-1-0              NK     1-M-63  CTRL
#
# [2806 rows x 26 columns]

# %% [markdown]
# ### Preprocess

# %%
sc.pl.highest_expr_genes(adata, n_top=20, )
# Out:
# /beevol/home/davidson/miniconda3/envs/sc_bulk_ood/lib/python3.9/site-packages/seaborn/categorical.py:82: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   plot_data = [np.asarray(s, float) for k, s in iter_data]

# %%
# check we don't have any weird cell types
adata.obs["scpred_CellType"].value_counts()
# Out:
# hepatocyte                     1043
# kupffer                         724
# hepatic_stellate_sinusoid       452
# NK                              353
# myeloid_leukocyte               119
# b_cell                           84
# plasmacytoid_dendritic_cell      31
# Name: scpred_CellType, dtype: int64

# %%
# write out data for BP and cibersort
dense_matrix = adata.X.todense()

sc_profile_file = os.path.join(aug_data_path, f"{res_name}_sig.pkl")
sc_profile_path = Path(sc_profile_file)

dense_df = pd.DataFrame(dense_matrix, columns = adata.var['gene_ids'])
dense_df.insert(loc=0, column='scpred_CellType', value=adata.obs["scpred_CellType"].to_list())


pickle.dump( dense_df, open( sc_profile_path, "wb" ) )

# %%
dense_matrix.shape
# Out:
# (2806, 14829)

# %% [markdown]
# # Plot Data

# %%
# valculate neighborhood graph
sc.pp.neighbors(adata)

# make umap
sc.tl.umap(adata)

# plot some markers of the RAW data
sc.pl.umap(adata, legend_loc='on data', color='scpred_CellType', legend_fontsize=8)

# %% [markdown]
# # Make Pseudobulks

# %% [markdown]
# ### First do some QC stats

# %%
adata.obs["sample_id"].value_counts()
# Out:
# 1-M-63     1933
# 18-F-51     547
# 30-M-5      326
# Name: sample_id, dtype: int64

# %%
adata.obs
# Out:
#                            age batch  \
# index
# AAAGCAATCGGAAATA-1-9-0-0   18m     0
# AACTCCCAGTTGTCGT-1-9-0-0   Hepatocyte (Pericentral, Midlobular, Periportal)
# AACTCCCGTAACGTTC-1-9-0-0   Hepatocyte (Pericentral, Midlobular, Periportal)
# ...                                                                     ...
# TTTGCGCTCGTTTATC-1-50-1-0                                      Kupffer cell
# TTTGGTTAGAACTGTA-1-50-1-0                          Hepatocyte (Pericentral)
# TTTGGTTAGGAGTACC-1-50-1-0                                      Kupffer cell
# TTTGGTTGTAGCGCAA-1-50-1-0                                      Kupffer cell
# TTTGTCACAAATCCGT-1-50-1-0                                              NK/T
#
#                             method mouse.id  n_genes     sex  ...  \
# index                                                         ...
# AAAGCAATCGGAAATA-1-9-0-0   droplet  18-F-51     1976  female  ...
# AAAGTAGAGGCCCTTG-1-9-0-0   droplet  18-F-51     1897  female  ...
# AACCGCGAGAAACCGC-1-9-0-0   droplet  18-F-51     1501  female  ...
# AACTCCCAGTTGTCGT-1-9-0-0   droplet  18-F-51     1710  female  ...
# AACTCCCGTAACGTTC-1-9-0-0   droplet  18-F-51     1432  female  ...
# ...                            ...      ...      ...     ...  ...
# TTTGCGCTCGTTTATC-1-50-1-0  droplet   1-M-63     1856    male  ...
# TTTGGTTAGAACTGTA-1-50-1-0  droplet   1-M-63     1404    male  ...
# TTTGGTTAGGAGTACC-1-50-1-0  droplet   1-M-63     2694    male  ...
# TTTGGTTGTAGCGCAA-1-50-1-0  droplet   1-M-63     2359    male  ...
# TTTGTCACAAATCCGT-1-50-1-0  droplet   1-M-63     1483    male  ...
#
#                           names_merged keep n_genes_by_counts  total_counts  \
# index
# AAAGCAATCGGAAATA-1-9-0-0    hepatocyte  yes              1976   7407.838867
# AAAGTAGAGGCCCTTG-1-9-0-0    hepatocyte  yes              1897   7719.286621
# AACCGCGAGAAACCGC-1-9-0-0    hepatocyte  yes              1501   6661.215332
# AACTCCCAGTTGTCGT-1-9-0-0    hepatocyte  yes              1710   6938.270020
# AACTCCCGTAACGTTC-1-9-0-0    hepatocyte  yes              1432   6389.012695
# ...                                ...  ...               ...           ...
# TTTGCGCTCGTTTATC-1-50-1-0      kupffer  yes              1856   5283.314453
# TTTGGTTAGAACTGTA-1-50-1-0   hepatocyte  yes              1403   4763.772461
# TTTGGTTAGGAGTACC-1-50-1-0      kupffer  yes              2694   6832.473633
# TTTGGTTGTAGCGCAA-1-50-1-0      kupffer  yes              2359   6148.290039
# TTTGTCACAAATCCGT-1-50-1-0           NK  yes              1483   4487.968262
#
#                           total_counts_mt pct_counts_mt    CellType  \
# index
# AAAGCAATCGGAAATA-1-9-0-0              0.0           0.0  hepatocyte
# AAAGTAGAGGCCCTTG-1-9-0-0              0.0           0.0  hepatocyte
# AACCGCGAGAAACCGC-1-9-0-0              0.0           0.0  hepatocyte
# AACTCCCAGTTGTCGT-1-9-0-0              0.0           0.0  hepatocyte
# AACTCCCGTAACGTTC-1-9-0-0              0.0           0.0  hepatocyte
# ...                                   ...           ...         ...
# TTTGCGCTCGTTTATC-1-50-1-0             0.0           0.0     kupffer
# TTTGGTTAGAACTGTA-1-50-1-0             0.0           0.0  hepatocyte
# TTTGGTTAGGAGTACC-1-50-1-0             0.0           0.0     kupffer
# TTTGGTTGTAGCGCAA-1-50-1-0             0.0           0.0     kupffer
# TTTGTCACAAATCCGT-1-50-1-0             0.0           0.0          NK
#
#                           scpred_CellType  sample_id  stim
# index
# AAAGCAATCGGAAATA-1-9-0-0       hepatocyte    18-F-51  STIM
# AAAGTAGAGGCCCTTG-1-9-0-0       hepatocyte    18-F-51  STIM
# AACCGCGAGAAACCGC-1-9-0-0       hepatocyte    18-F-51  STIM
# AACTCCCAGTTGTCGT-1-9-0-0       hepatocyte    18-F-51  STIM
# AACTCCCGTAACGTTC-1-9-0-0       hepatocyte    18-F-51  STIM
# ...                                   ...        ...   ...
# TTTGCGCTCGTTTATC-1-50-1-0         kupffer     1-M-63  CTRL
# TTTGGTTAGAACTGTA-1-50-1-0      hepatocyte     1-M-63  CTRL
# TTTGGTTAGGAGTACC-1-50-1-0         kupffer     1-M-63  CTRL
# TTTGGTTGTAGCGCAA-1-50-1-0         kupffer     1-M-63  CTRL
# TTTGTCACAAATCCGT-1-50-1-0              NK     1-M-63  CTRL
#
# [2806 rows x 26 columns]

# %%
adata.obs["scpred_CellType"].unique()
# Out:
# ['hepatocyte', 'hepatic_stellate_sinusoid', 'kupffer', 'NK', 'plasmacytoid_dendritic_cell', 'b_cell', 'myeloid_leukocyte']
# Categories (7, object): ['NK', 'b_cell', 'hepatic_stellate_sinusoid', 'hepatocyte', 'kupffer', 'myeloid_leukocyte', 'plasmacytoid_dendritic_cell']

# %% [markdown]
# ### now split test and train cells

# %%
# generate cell-type specific split
adata.obs["isTraining"] = "Train"


stim_idx = np.where(adata.obs.stim == "STIM")[0]
adata.obs["isTraining"][stim_idx] = "Test"
# Out:
# <ipython-input-20-6097bf4a867b>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   adata.obs["isTraining"][stim_idx] = "Test"

# %%
pd.set_option('display.max_rows', 160)

tab = adata.obs.groupby(['stim', 'isTraining']).size()

tab.unstack()
# Out:
# isTraining  Test  Train
# stim
# CTRL           0   2259
# STIM         547      0

# %%
tab = adata.obs.groupby(['isTraining', 'sample_id']).size()

tab.unstack()
# Out:
# sample_id   1-M-63  18-F-51  30-M-5
# isTraining
# Test             0      547       0
# Train         1933        0     326

# %%
tab = adata.obs.groupby(['stim', 'sample_id']).size()

tab.unstack()
# Out:
# sample_id  1-M-63  18-F-51  30-M-5
# stim
# CTRL         1933        0     326
# STIM            0      547       0

# %% [markdown]
# ## Make pseudobulks

# %%
# write out the gene ids
gene_pass = adata.var['gene_ids']
gene_out_file = os.path.join(aug_data_path, f"{res_name}_genes.pkl")
gene_out_path = Path(gene_out_file)
pickle.dump( gene_pass, open( gene_out_path, "wb" ) )

# metadata
sample_order = ['1-M-63', '18-F-51', '30-M-5']
stim_order = ['STIM', 'CTRL']
train_order = ['Train', 'Test']

# now generate all the proportions
total_meta_df = pd.DataFrame(columns = ["sample_id", "stim", "isTraining"])

# no cell noise 
len_vector = adata.obs["scpred_CellType"].unique().shape[0]
cell_noise = [np.random.lognormal(0, 0, adata.var['gene_ids'].shape[0]) for i in range(len_vector)]

# cell type order
cell_order = adata.obs.scpred_CellType.unique()

# simulate different number of cells
num_cells = 5000
idx = 0
for curr_samp in sample_order:
  for curr_stim in stim_order:
      for curr_train in train_order:

        print(f"running {curr_samp} {curr_stim} {curr_train}")


        # make the pseudobulks
        subset_idx = np.logical_and(adata.obs.sample_id == curr_samp, adata.obs.stim == curr_stim)
        subset_idx = np.where(np.logical_and(subset_idx, adata.obs.isTraining == curr_train))[0]
        if len(subset_idx) == 0:
            continue
        
        temp_adata = adata[subset_idx]

        print("make_prop_and_sum")
        prop_df, pseudobulks_df, test_prop_df, test_pseudobulks_df = sc_preprocess.make_prop_and_sum(temp_adata, 
                                                                                num_samples=1000, 
                                                                                num_cells=num_cells,
                                                                                use_true_prop=False,
                                                                                cell_noise=cell_noise,
                                                                                useSampleNoise=False)

        # get the single cell type proportions
        print("get_single_celltype_prop_matrix")
        ct_prop_df = sc_preprocess.get_single_celltype_prop_matrix(num_samp=100,
                                                                    cell_order=cell_order)

        # now get the cell-type specific pseudobulks
        print("use_prop_make_sum")
        prop_df_sc, pseudobulks_df_sc, _ = sc_preprocess.use_prop_make_sum(temp_adata,  
                                                                            num_cells=num_cells, 
                                                                            props_vec=ct_prop_df, 
                                                                            cell_noise=cell_noise,
                                                                            sample_noise=None,
                                                                            useSampleNoise=False)

        # put them together
        print("concat")        
        prop_df = pd.concat([prop_df,prop_df_sc])
        pseudobulks_df = pd.concat([pseudobulks_df, pseudobulks_df_sc])

        # make the proportions instead of cell counts
        prop_df = prop_df.div(prop_df.sum(axis=1), axis=0)
        pseudobulk_file = os.path.join(aug_data_path, f"{res_name}_{curr_samp}_{curr_stim}_{curr_train}_pseudo_splits.pkl")
        prop_file = os.path.join(aug_data_path, f"{res_name}_{curr_samp}_{curr_stim}_{curr_train}_prop_splits.pkl")

        print("write")        
        pseudobulk_path = Path(pseudobulk_file)
        prop_path = Path(prop_file)
        pickle.dump( prop_df, open( prop_path, "wb" ) )
        pickle.dump( pseudobulks_df, open( pseudobulk_path, "wb" ) )
# Out:
# running 1-M-63 STIM Train
# running 1-M-63 STIM Test
# running 1-M-63 CTRL Train
# make_prop_and_sum
# 0
# 100
# 200
# 300
# 400
# 500
# 600
# 700
# 800
# 900
# 1000
# get_single_celltype_prop_matrix
# use_prop_make_sum
# 0
# 100
# 200
# 300
# 400
# 500
# 600
# concat
# write
# running 1-M-63 CTRL Test
# running 18-F-51 STIM Train
# running 18-F-51 STIM Test
# make_prop_and_sum
# 0
# 100
# 200
# 300
# 400
# 500
# 600
# 700
# 800
# 900
# 1000
# get_single_celltype_prop_matrix
# use_prop_make_sum
# 0
# 100
# 200
# 300
# 400
# 500
# 600
# concat
# write
# running 18-F-51 CTRL Train
# running 18-F-51 CTRL Test
# running 30-M-5 STIM Train
# running 30-M-5 STIM Test
# running 30-M-5 CTRL Train
# make_prop_and_sum
# 0
# 100
# 200
# 300
# 400
# 500
# 600
# 700
# 800
# 900
# 1000
# get_single_celltype_prop_matrix
# use_prop_make_sum
# 0
# 100
# 200
# 300
# 400
# 500
# 600
# concat
# write
# running 30-M-5 CTRL Test
